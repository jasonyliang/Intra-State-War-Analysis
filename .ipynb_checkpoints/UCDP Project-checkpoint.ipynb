# %%
# libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
# code book available at: https://ucdp.uu.se/downloads/brd/ucdp-brd-191.pdf

# %%
# import data
data = pd.read_csv("data/UCDPBattleDeath.csv", encoding='latin-1')
data.head()
# Out:
#    conflict_id  dyad_id location_inc              side_a side_a_id side_a_2nd  \
# 0          205      406         Iran  Government of Iran       114        NaN
# 1          205      406         Iran  Government of Iran       114        NaN
# 2          205      406         Iran  Government of Iran       114        NaN
# 3          205      406         Iran  Government of Iran       114        NaN
# 4          205      406         Iran  Government of Iran       114        NaN
#
#   side_b side_b_id side_b_2nd  incompatibility   ...   type_of_conflict  \
# 0   KDPI       164        NaN                1   ...                  3
# 1   KDPI       164        NaN                1   ...                  3
# 2   KDPI       164        NaN                1   ...                  3
# 3   KDPI       164        NaN                1   ...                  3
# 4   KDPI       164        NaN                1   ...                  3
#
# ...

# %%
list(data)
# Out:
# ['conflict_id',
#  'dyad_id',
#  'location_inc',
#  'side_a',
#  'side_a_id',
#  'side_a_2nd',
#  'side_b',
#  'side_b_id',
#  'side_b_2nd',
#  'incompatibility',
#  'territory_name',
#  'year',
#  'bd_best',
#  'bd_low',
#  'bd_high',
#  'type_of_conflict',
#  'battle_location',
#  'gwno_a',
#  'gwno_a_2nd',
#  'gwno_b',
#  'gwno_b_2nd',
#  'gwno_loc',
#  'gwno_battle',
#  'region',
#  'version']

# %%
data.describe()
# Out:
#         conflict_id       dyad_id  incompatibility         year       bd_best  \
# count   1565.000000   1565.000000      1565.000000  1565.000000   1565.000000
# mean    1441.824281   2824.247284         1.549521  2003.270927    900.244089
# std     3582.614254   4777.670133         0.500263     9.082850   3722.826610
# min      205.000000    406.000000         1.000000  1989.000000     25.000000
# 25%      288.000000    624.000000         1.000000  1995.000000     43.000000
# 50%      333.000000    754.000000         2.000000  2003.000000    118.000000
# 75%      388.000000    869.000000         2.000000  2012.000000    489.000000
# max    14609.000000  15895.000000         3.000000  2018.000000  68614.000000
#
#              bd_low       bd_high  type_of_conflict       version
# count   1565.000000   1565.000000       1565.000000  1.565000e+03
# mean     786.077955   1156.854952          3.150799  1.910000e+01
# std     2862.735593   4064.040425          0.411170  3.553849e-15
# ...

# %%
# We only want to look at intra wars
intra_data = data[data['type_of_conflict'] == 3]
intra_data.head()
# Out:
#    conflict_id  dyad_id location_inc              side_a side_a_id side_a_2nd  \
# 0          205      406         Iran  Government of Iran       114        NaN
# 1          205      406         Iran  Government of Iran       114        NaN
# 2          205      406         Iran  Government of Iran       114        NaN
# 3          205      406         Iran  Government of Iran       114        NaN
# 4          205      406         Iran  Government of Iran       114        NaN
#
#   side_b side_b_id side_b_2nd  incompatibility   ...   type_of_conflict  \
# 0   KDPI       164        NaN                1   ...                  3
# 1   KDPI       164        NaN                1   ...                  3
# 2   KDPI       164        NaN                1   ...                  3
# 3   KDPI       164        NaN                1   ...                  3
# 4   KDPI       164        NaN                1   ...                  3
#
# ...

# %%
intra_data.describe()
# Out:
#         conflict_id       dyad_id  incompatibility         year       bd_best  \
# count   1265.000000   1265.000000      1265.000000  1265.000000   1265.000000
# mean    1197.124111   2573.342292         1.511462  2002.406324    610.649012
# std     3196.241538   4517.745774         0.503220     8.864716   3071.442584
# min      205.000000    406.000000         1.000000  1989.000000     25.000000
# 25%      288.000000    623.000000         1.000000  1994.000000     40.000000
# 50%      329.000000    747.000000         2.000000  2002.000000     97.000000
# 75%      386.000000    853.000000         2.000000  2010.000000    334.000000
# max    14333.000000  15895.000000         3.000000  2018.000000  68614.000000
#
#              bd_low       bd_high  type_of_conflict       version
# count   1265.000000   1265.000000            1265.0  1.265000e+03
# mean     500.252964    809.103557               3.0  1.910000e+01
# std     1669.812129   3364.771606               0.0  7.108237e-15
# ...

# %%
# lethality over the years
plt.scatter(intra_data['year'], intra_data['bd_best'])

# %%
# zoom in
# remove outliers
lower_leth = intra_data[intra_data['bd_best']<10000]
plt.scatter(lower_leth['year'], lower_leth['bd_best'])

# %%
# regions
def pie_chart_region(wars, startyears = None, endyears=None):
    if endyears and startyears:
        wars = wars[(wars["year"] < endyears) &(wars["year"] > startyears)]
    elif endyears:
        wars = wars[wars["year"] < endyears]
    elif startyears:
        wars = wars[wars["year"] > startyears]
    regions = {1:"Europe", 2: "Middle East", 3: "Asia", 4: "Africa", 5: "Americas"}
    size = []
    names = []
    for num, region in regions.items():
        numWars = wars[wars['region']==str(num)].count(axis=0)[0]
        names.append(region)
        size.append(numWars)
    plt.pie(size, labels=names, autopct='%1.1f%%', shadow=True, startangle=140)
    plt.axis('equal')
    plt.tight_layout()

# %%
# post 1990
pie_chart_region(intra_data, startyears=1990)

# %%
# all intra-war in the data set
pie_chart_region(intra_data)
